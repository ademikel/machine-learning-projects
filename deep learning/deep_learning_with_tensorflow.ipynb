# %%
import tensorflow as tf

tf.__version__
# Out:
# '2.7.0'

# %% [markdown]
# #### Building and Running a computational graph can be done once

# %% [markdown]
# ##### constant varibles

# %%
node1 = tf.constant(3.0)
node2 = tf.constant(4.0)

print(node1, node2)
# Out:
# tf.Tensor(3.0, shape=(), dtype=float32) tf.Tensor(4.0, shape=(), dtype=float32)

# %%
a = tf.constant(5)
b = tf.constant(2)
c = tf.constant(3)

d = tf.multiply(a, b)
e = tf.add(c, b)

f = tf.subtract(d, e)

print(f)
# Out:
# tf.Tensor(5, shape=(), dtype=int32)

# %%
x
# Out:
# --------------------------------------------------------------------------
# AttributeError                           Traceback (most recent call last)
# <ipython-input-4-f75057d1d95f> in <module>
# ----> 1 sess = tf.Session()
#
# AttributeError: module 'tensorflow' has no attribute 'Session'

# %% [markdown]
# ##### placeolders

# %%
a = tf.placeholder()
b = tf.placeholder()

add_node = a + b

print(add_node, {a : [1, 3], b : [2, 4]})
# Out:
# --------------------------------------------------------------------------
# AttributeError                           Traceback (most recent call last)
# <ipython-input-6-a935120e883f> in <module>
# ----> 1 a = tf.PlaceHolder()
#       2 b = tf.PlaceHolder()
#       3
#       4 add_node = a + b
#       5
#
# AttributeError: module 'tensorflow' has no attribute 'PlaceHolder'

# %%
x = tf.Variable([.3])
y = tf.Variable([-.3])

linear_model = x * y
init = tf.global_variables_initializer() 

init

print(linear_model)
# Out:
# --------------------------------------------------------------------------
# AttributeError                           Traceback (most recent call last)
# <ipython-input-7-12cf6ce585b9> in <module>
#       3
#       4 linear_model = x * y
# ----> 5 init = tf.global_variables_initializer()
#       6
#       7 print(linear_model)
#
# AttributeError: module 'tensorflow' has no attribute 'global_variables_initializer'
